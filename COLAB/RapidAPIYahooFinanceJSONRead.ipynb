# %% [markdown]
# <a href="https://colab.research.google.com/github/MarkovMarkowitz/MarkovMarkowitz/blob/main/RapidAPIYahooFinanceJSONRead.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

url = "https://yahoo-finance127.p.rapidapi.com/historic/XU100.IS/1h/3mo"

headers = {
	"X-RapidAPI-Key": "c4100a6817msh6100fdd804b1ae8p1defa4jsn72757c98b3c0",
	"X-RapidAPI-Host": "yahoo-finance127.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'meta': {'currency': 'TRY', 'symbol': 'XU100.IS', 'exchangeName': 'IST', 'instrumentType': 'INDEX', 'firstTradeDate': 867738600, 'regularMarketTime': 1692261967, 'gmtoffset': 10800, 'timezone': 'TRT', 'exchangeTimezoneName': 'Europe/Istanbul', 'regularMarketPrice': 7749.1, 'chartPreviousClose': 4661.7, 'previousClose': 7662.26, 'scale': 3, 'priceHint': 2, 'currentTradingPeriod': {'pre': {'timezone': 'TRT', 'start': 1692253800, 'end': 1692253800, 'gmtoffset': 10800}, 'regular': {'timezone': 'TRT', 'start': 1692253800, 'end': 1692284400, 'gmtoffset': 10800}, 'post': {'timezone': 'TRT', 'start': 1692284400, 'end': 1692284400, 'gmtoffset': 10800}}, 'tradingPeriods': [[{'timezone': 'TRT', 'start': 1684305000, 'end': 1684335600, 'gmtoffset': 10800}], [{'timezone': 'TRT', 'start': 1684391400, 'end': 1684422000, 'gmtoffset': 10800}], [{'timezone': 'TRT', 'start': 1684737000, 'end': 1684767600, 'gmtoffset': 10800}], [{'timezone': 'TRT', 'start': 1684823400, 'end': 1684854000, 'gmtoffset': 10
# ...

# %%
# Python program to read
# json file

import json

# Opening JSON file
#f = open(response.json())

# returns JSON object as
# a dictionary
#data = json.load(f)
data = response.json()

# Iterating through the json
# list
from datetime import datetime

for i in data['timestamp']:
	dt_obj = datetime.fromtimestamp(i)
	print(i,dt_obj)

print("date_time:",dt_obj)
print("type of dt:",type(dt_obj))

# Closing file

print(data)


for json_object in data_in_file:
  print("ttl: %s, desc: %s" % (json_object['title'],json_object['description']) )
# Out:
# 1684312200 2023-05-17 08:30:00
# 1684315800 2023-05-17 09:30:00
# 1684319400 2023-05-17 10:30:00
# 1684323000 2023-05-17 11:30:00
# 1684326600 2023-05-17 12:30:00
# 1684330200 2023-05-17 13:30:00
# 1684333800 2023-05-17 14:30:00
# 1684391400 2023-05-18 06:30:00
# 1684395000 2023-05-18 07:30:00
# 1684398600 2023-05-18 08:30:00
# 1684402200 2023-05-18 09:30:00
# 1684405800 2023-05-18 10:30:00
# 1684409400 2023-05-18 11:30:00
# 1684413000 2023-05-18 12:30:00
# 1684416600 2023-05-18 13:30:00
# 1684420200 2023-05-18 14:30:00
# 1684737000 2023-05-22 06:30:00
# 1684740600 2023-05-22 07:30:00
# 1684744200 2023-05-22 08:30:00
# 1684747800 2023-05-22 09:30:00
# 1684751400 2023-05-22 10:30:00
# 1684755000 2023-05-22 11:30:00
# 1684758600 2023-05-22 12:30:00
# 1684762200 2023-05-22 13:30:00
# 1684765800 2023-05-22 14:30:00
# 1684823400 2023-05-23 06:30:00
# 1684827000 2023-05-23 07:30:00
# 1684830600 2023-05-23 08:30:00
# 1684834200 2023-05-23 09:30:00
# 1684837800 2023-05-23 10:30:00
# ...

# %%
# !pip3 install tabulate
import tabulate
import pandas as pd
#print(tabulate(data['timestamp']))

#with open("data.json") as myFile:
dataFrame = pd.DataFrame.from_dict(data['timestamp'])
print(dataFrame)
